# %%
from sstm import estimate_flow

# %%
from sstm import estimate_flow

f1, _ = estimate_flow(
    "checkpoints/sstm_t++-sintel.pth",
    "frame_0013.png",
    "frame_0014.png"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from sstm import estimate_flow
# ----> 3 f1, _ = estimate_flow(
#       4     "checkpoints/sstm_t++-sintel.pth",
#       5     "frame_0013.png",
#       6     "frame_0014.png"
#       7 )
#
# File ~\anaconda3\envs\cvflow\lib\site-packages\sstm\inference.py:200, in estimate_flow(model_path, img1, img2, img3, iters, output_dir, save_flo, save_vis_outputs, save_f2, model_args, device)
#     191 """
#     192 High-level entry point for PyPI users.
#     193
#    (...)
#     197   - f2 is flow from img2 -> img3 (or img2 -> img2 if img3 is None)
#     198 """
#     199 model = load_model(model_path, model_args=model_args, device=device)
# --> 200 f1, f2 = infer_flow_triplet(model, img1, img2, img3=img3, iters=iters, device=device)
#     202 save_second = img3 is not None or save_f2
# ...
